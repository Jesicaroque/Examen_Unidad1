# %%
import matplotlib.pyplot as plt
import numpy as np
  
empresas = ['Facebook', 'Apple', 'Amazon', 'Netflix', 'Google']
  
marketCap = [856.555, 2241, 1695, 225.389, 1541]
  
fig = plt.figure(figsize = (10, 7))
plt.pie(marketCap, labels = empresas)
plt.title("Market Cap FAANG (B)")

plt.show()
