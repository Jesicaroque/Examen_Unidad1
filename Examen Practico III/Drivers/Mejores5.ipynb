# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

best = []

dfam = pd.read_csv('amazon.csv').astype(str)
dfap = pd.read_csv('apple.csv').astype(str)
dfbl = pd.read_csv('blockchain.csv').astype(str)
dfbm = pd.read_csv('bmw.csv').astype(str)
dfco = pd.read_csv('coinbase.csv').astype(str)
dfde = pd.read_csv('dell.csv').astype(str)
dffa = pd.read_csv('facebook.csv').astype(str)
dfgo = pd.read_csv('google.csv').astype(str)
dfhu = pd.read_csv('huawei.csv').astype(str)
dfle = pd.read_csv('lenovo.csv').astype(str)
dfmi = pd.read_csv('microsoft.csv').astype(str)
dfni = pd.read_csv('nissan.csv').astype(str)
dfpi = pd.read_csv('pinteres.csv').astype(str)
dfse = pd.read_csv('seika.csv').astype(str)
dfte = pd.read_csv('tesla.csv').astype(str)
dftr = pd.read_csv('trust.csv').astype(str)
dftw = pd.read_csv('twitter.csv').astype(str)
dfub = pd.read_csv('uber.csv').astype(str)

dfae = pd.read_csv('aerosystems.csv').astype(str)
dfar = pd.read_csv('aerovironment.csv').astype(str)
dfai = pd.read_csv('airbus.csv').astype(str)
dfbi = pd.read_csv('biosciences.csv').astype(str)
dfcr = pd.read_csv('cord.csv').astype(str)
dfep = pd.read_csv('epson.csv').astype(str)
dffo = pd.read_csv('ford.csv').astype(str)
dfha = pd.read_csv('hasbro.csv').astype(str)
dfil = pd.read_csv('illumina.csv').astype(str)
dfmr = pd.read_csv('mirati.csv').astype(str)
dfna = pd.read_csv('nano.csv').astype(str)
dfnk = pd.read_csv('nike.csv').astype(str)
dfno = pd.read_csv('novocure.csv').astype(str)
dfre = pd.read_csv('regenxbio.csv').astype(str)
dfun = pd.read_csv('uniqure.csv').astype(str)


def formatito():
    
    dfam['Date'] = pd.to_datetime(dfam['Date'], format="%b %d, %Y")
    dfap['Date'] = pd.to_datetime(dfap['Date'], format="%b %d, %Y")
    dfbl['Date'] = pd.to_datetime(dfbl['Date'], format="%b %d, %Y")
    dfbm['Date'] = pd.to_datetime(dfbm['Date'], format="%b %d, %Y")
    dfco['Date'] = pd.to_datetime(dfco['Date'], format="%b %d, %Y")
    dfde['Date'] = pd.to_datetime(dfde['Date'], format="%b %d, %Y")
    dffa['Date'] = pd.to_datetime(dffa['Date'], format="%b %d, %Y")
    dfgo['Date'] = pd.to_datetime(dfgo['Date'], format="%b %d, %Y")
    dfhu['Date'] = pd.to_datetime(dfhu['Date'], format="%b %d, %Y")
    dfle['Date'] = pd.to_datetime(dfle['Date'], format="%b %d, %Y")
    dfmi['Date'] = pd.to_datetime(dfmi['Date'], format="%b %d, %Y")
    dfni['Date'] = pd.to_datetime(dfni['Date'], format="%b %d, %Y")
    dfpi['Date'] = pd.to_datetime(dfpi['Date'], format="%b %d, %Y")
    dfse['Date'] = pd.to_datetime(dfse['Date'], format="%b %d, %Y")
    dfte['Date'] = pd.to_datetime(dfte['Date'], format="%b %d, %Y")
    dftr['Date'] = pd.to_datetime(dftr['Date'], format="%b %d, %Y")
    dftw['Date'] = pd.to_datetime(dftw['Date'], format="%b %d, %Y")
    dfub['Date'] = pd.to_datetime(dfub['Date'], format="%b %d, %Y")
    
    dfae['Date'] = pd.to_datetime(dfae['Date'], format="%b %d, %Y")
    dfar['Date'] = pd.to_datetime(dfar['Date'], format="%b %d, %Y")
    dfai['Date'] = pd.to_datetime(dfai['Date'], format="%b %d, %Y")
    dfbi['Date'] = pd.to_datetime(dfbi['Date'], format="%b %d, %Y")
    dfcr['Date'] = pd.to_datetime(dfcr['Date'], format="%b %d, %Y")
    dfep['Date'] = pd.to_datetime(dffo['Date'], format="%b %d, %Y")
    dffo['Date'] = pd.to_datetime(dfep['Date'], format="%b %d, %Y")
    dfha['Date'] = pd.to_datetime(dfha['Date'], format="%b %d, %Y")
    dfil['Date'] = pd.to_datetime(dfil['Date'], format="%b %d, %Y")
    dfmr['Date'] = pd.to_datetime(dfmr['Date'], format="%b %d, %Y")
    dfna['Date'] = pd.to_datetime(dfna['Date'], format="%b %d, %Y")
    dfnk['Date'] = pd.to_datetime(dfnk['Date'], format="%b %d, %Y")
    dfno['Date'] = pd.to_datetime(dfno['Date'], format="%b %d, %Y")
    dfre['Date'] = pd.to_datetime(dfre['Date'], format="%b %d, %Y")
    dfun['Date'] = pd.to_datetime(dfun['Date'], format="%b %d, %Y")
    
    dfam['Close'] = dfam['Close'].str.replace(',', '')
    dfam['Close'] = pd.to_numeric(dfam['Close'], errors = 'coerce')
    dfap['Close'] = pd.to_numeric(dfap['Close'], errors = 'coerce')
    dfbl['Close'] = pd.to_numeric(dfbl['Close'], errors = 'coerce')
    dfbm['Close'] = pd.to_numeric(dfbm['Close'], errors = 'coerce')
    dfco['Close'] = pd.to_numeric(dfco['Close'], errors = 'coerce')
    dfde['Close'] = pd.to_numeric(dfde['Close'], errors = 'coerce')
    dffa['Close'] = pd.to_numeric(dffa['Close'], errors = 'coerce')
    dfgo['Close'] = dfgo['Close'].str.replace(',', '')
    dfgo['Close'] = pd.to_numeric(dfgo['Close'], errors = 'coerce')
    dfhu['Close'] = dfhu['Close'].str.replace(',', '')
    dfhu['Close'] = pd.to_numeric(dfhu['Close'], errors = 'coerce')
    dfle['Close'] = pd.to_numeric(dfle['Close'], errors = 'coerce')
    dfmi['Close'] = pd.to_numeric(dfmi['Close'], errors = 'coerce')
    dfni['Close'] = pd.to_numeric(dfni['Close'], errors = 'coerce')
    dfpi['Close'] = pd.to_numeric(dfpi['Close'], errors = 'coerce')
    dfse['Close'] = dfse['Close'].str.replace(',', '')
    dfse['Close'] = pd.to_numeric(dfse['Close'], errors = 'coerce')
    dfte['Close'] = pd.to_numeric(dfte['Close'], errors = 'coerce')
    dftr['Close'] = pd.to_numeric(dftr['Close'], errors = 'coerce')
    dftw['Close'] = pd.to_numeric(dftw['Close'], errors = 'coerce')
    dfub['Close'] = pd.to_numeric(dfub['Close'], errors = 'coerce')
    
    dfae['Close'] = pd.to_numeric(dfae['Close'], errors = 'coerce')
    dfar['Close'] = pd.to_numeric(dfar['Close'], errors = 'coerce')
    dfai['Close'] = pd.to_numeric(dfai['Close'], errors = 'coerce')
    dfbi['Close'] = pd.to_numeric(dfbi['Close'], errors = 'coerce')
    dfcr['Close'] = pd.to_numeric(dfcr['Close'], errors = 'coerce')
    dfep['Close'] = pd.to_numeric(dfep['Close'], errors = 'coerce')
    dffo['Close'] = pd.to_numeric(dffo['Close'], errors = 'coerce')
    dfha['Close'] = pd.to_numeric(dfha['Close'], errors = 'coerce')
    dfil['Close'] = pd.to_numeric(dfil['Close'], errors = 'coerce')
    dfmr['Close'] = pd.to_numeric(dfmr['Close'], errors = 'coerce')
    dfna['Close'] = pd.to_numeric(dfna['Close'], errors = 'coerce')
    dfnk['Close'] = pd.to_numeric(dfnk['Close'], errors = 'coerce')
    dfno['Close'] = pd.to_numeric(dfno['Close'], errors = 'coerce')
    dfre['Close'] = pd.to_numeric(dfre['Close'], errors = 'coerce')
    dfun['Close'] = pd.to_numeric(dfun['Close'], errors = 'coerce')
    
def intervalos(dff_20, nm):
    print(nm)
    print("La media es: {}".format(dff_20['Close'].mean()))
    #print("La moda es: {}".format(dff_20['Close'].mode()))
    print("La mediana es: {}".format(dff_20['Close'].median()))
    print("La desviación estándar es de: {}\n".format(np.std(dff_20['Close'])))
    
    valUno = dff_20.loc[dff_20['Date'] == dff_20['Date'].min()]['Open']
    valDos = dff_20.loc[dff_20['Date'] == dff_20['Date'].max()]['Close']
    #print('Open {}\tClose {}\tFecha min: {}\tFecha max: {}'.format(valUno.values[0], valDos.values[0], dff_20['Date'].min(), dff_20['Date'].max()))
    if pd.to_numeric(valUno.values[0], errors = 'coerce') == 0:
        return (pd.to_numeric(valDos.values[0], errors = 'coerce')*100)/1
    return (pd.to_numeric(valDos.values[0], errors = 'coerce')*100)/pd.to_numeric(valUno.values[0], errors = 'coerce')
    
def rendimiento():
    dic2020 = {
        'Facebook': intervalos(dffa, "Facebook"),
        'Amazon': intervalos(dfam, "Amazon"),
        'Apple': intervalos(dfap, "Apple"),
        'Google': intervalos(dfgo, "Google"),
        'bloackchain': intervalos(dfbl, "Bloackchain"),
        'BMW': intervalos(dfbm, "BMW"),
        'Coinbase': intervalos(dfco, "Coinbase"),
        'Dell': intervalos(dfde, "Dell"),
        'Huawei': intervalos(dfhu, "Huawei"),
        'Lenovo': intervalos(dfle, "Lenovo"),
        'Microsoft': intervalos(dfmi, "Microsoft"),
        'Nissan': intervalos(dfni, "Nissan"),
        'Pinterest': intervalos(dfpi, "Pinterest"),
        'Seika': intervalos(dfse, "Seika"),
        'Tesla': intervalos(dfte, "Tesla"),
        'Trust Wallet': intervalos(dftr, "Trust Wallet"),
        'Twitter': intervalos(dftw, "Twitter"),
        'Uber': intervalos(dfub, "Uber"),
        'AeroSystems': intervalos(dfae, "AeroSystems"),
        'AeroViroment': intervalos(dfar, "AeroViroment"),
        'Airbus': intervalos(dfai, "Airbus"),
        'Biosciences': intervalos(dfbi, "biosciences"),
        'Cord': intervalos(dfcr, "Cord"),
        'Epson': intervalos(dfep, "Epson"),
        'Ford': intervalos(dffo, "Ford"),
        'Hasbro': intervalos(dfha, "Hasbro"),
        'Illumina': intervalos(dfil, "Illumina"),
        'Mirati Therapeutics': intervalos(dfmi, "Mirati Therapeutics"),
        'Nano': intervalos(dfna, "Nano"),
        'Nike': intervalos(dfnk, "Nike"),
        'NovoCure': intervalos(dfno, "NovoCure"),
        'Regenxbio': intervalos(dfre, "Regenxbio"),
        'uniQure': intervalos(dfun, "uniQure")
    }
    
    
    a = sorted(dic2020, key=dic2020.get, reverse=True)[:5]
    print("5 empresas para invertir por su mayor rendimiento\n")
    
    for key in a:
        print("{}: {}". format(key, dic2020[key]))
    
    
formatito()
rendimiento()
# Out:
# Facebook
# La media es: 134.81284403669727
# La mediana es: 130.32
# La desviación estándar es de: 76.97272523125406
#
# Amazon
# La media es: 487.09363321799304
# La mediana es: 90.56
# La desviación estándar es de: 799.0909431392744
#
# Apple
# La media es: 12.75582191780822
# La mediana es: 0.58
# La desviación estándar es de: 24.58935046494562
#
# Google
# La media es: 602.9529702970297
# La mediana es: 386.02
# La desviación estándar es de: 490.0737601314675
#
# Bloackchain
# La media es: 7.762380952380952
# La mediana es: 3.5
# La desviación estándar es de: 11.069051480604475
#
# BMW
# La media es: 52.00095238095238
# La mediana es: 42.85
# La desviación estándar es de: 23.143379045653504
#
# Coinbase
# La media es: 298.87470588235294
# La mediana es: 297.64
# La desviación estándar es de: 22.259618969744313
#
# Dell
# La media es: 52.076379310344834
# La mediana es: 49.254999999999995
# La desviación estándar es de: 17.025986395879546
#
# Huawei
# ...
